# %% [markdown]
# ## WGlimpse (still in testing)
#
# the code computes the Wiener estimate and then runs Glimpse-on-a-grid on the shear residuals
#
# Instructions for the C++ code are,
#
# to compile from within a build directory
#
# ```
# mkdir build
# cd build
# cmake ..
# make
# ```
#
# to run wglimpse for mice data
#
# ```
#  rm *.fits; ./glimpse ../data/mice/fits_files/config2d.ini ../data/mice/fits_files/mice_g1_map_0.fits ../data/mice/fits_files/mice_g2_map_0.fits ../data/mice/fits_files/mice_cosmosis_ps1d_kappa.fits ../data/mice/fits_files/mice_noisecov_map.fits ../data/mice/fits_files/kappa_mice_fast_glimpse_0.fits > ../data/mice/output.txt
# ```
#
# the input arguments are
#
# config2d.ini                   -> the config file for fast glimpse
# mice_g1_map_0.fits             -> the binned g1 map
# mice_g2_map_0.fits             -> the binned g2 map
# mice_cosmosis_ps1d_kappa.fits  -> the 1d powerspectrum for the mice map based on the cosmosis module
# mice_noisecov_map.fits         -> the noise covariance map having a DES-like mask
# kappa_mice_fast_glimpse_0.fits -> the output file
#
#
# To disable wiener functionality and run Glimpse-on-a-grid only, comment out lines 33 of src/glimpse.cpp
# ```
# wf->main_iteration();
# ```
#
# DES data look much better than MICE but in this version I include a test MICE dataset

# %%
# %matplotlib inline

import numpy as np
from astropy.io import fits
from scipy import ndimage
import math
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = (15, 5); plt.rcParams.update({'font.size': 13});

# %%
# load mice data patch
e1_fnm = "../data/mice/sv_patches/e1_noisy_030419_0.npy"
e2_fnm = "../data/mice/sv_patches/e2_noisy_030419_0.npy"
ktr_fnm = "../data/mice/sv_patches/kappa_true_030419_0.npy" 

e1 = -np.load(e1_fnm) # e1 noisy
e2 = -np.load(e2_fnm) # e2 noisy  
ktr = np.load(ktr_fnm) # true kappa map

# %%
# check the noise covariance and power spectrum

Ncov = np.array(np.load('../data/mice/Ncov.npy') )
print('noise covariance map size', Ncov.shape)

npix = Ncov.shape[0]

ps1d = np.load('../data/mice/cosmosis_mice_power_spectrum1d.npy') 
print('power spectrum length', ps1d.shape)

index = np.where(Ncov<1e2)
ktr_mask = np.zeros((npix,npix))
ktr_mask[index] = ktr[index]
ktr_mask_flip = np.flip(ktr_mask, 1)


# plot data
fig1, [ax1, ax2] = plt.subplots(nrows=1, ncols=2)
cax1 = ax1.imshow(np.log10(Ncov), interpolation='none', cmap='inferno',vmin=-2.8,vmax=-1.1) 
ax1.set_title('noise covariance'), plt.colorbar(cax1, ax=ax1)
cax2 = ax2.plot(ps1d) 
ax2.set_title('Cosmosis mice powerspectrum'), ax2.set_yscale('log')
plt.show()

fig2, [ax1, ax2] = plt.subplots(nrows=1, ncols=2)
cax1 = ax1.imshow(e1, interpolation='none', cmap='inferno') 
ax1.set_title('e1'), plt.colorbar(cax1, ax=ax1)
cax2 = ax2.imshow(e2, interpolation='none', cmap='inferno') 
ax2.set_title('e2'), plt.colorbar(cax2, ax=ax2)

fig2, [ax1, ax2] = plt.subplots(nrows=1, ncols=2)
cax1 = ax1.imshow(ktr, interpolation='none', cmap='inferno') 
ax1.set_title('kappa true'), plt.colorbar(cax1, ax=ax1)
cax2 = ax2.imshow((ktr), interpolation='none', cmap='inferno') 
ax2.set_title('Ncov'), plt.colorbar(cax2, ax=ax2)

plt.show()
# Out:
# noise covariance map size (256, 256)
# power spectrum length (182,)

# %%
fig2, [ax1, ax2] = plt.subplots(nrows=1, ncols=2)
cax1 = ax1.imshow(Ncov, interpolation='none', cmap='inferno', origin='lower') 
ax1.set_title('Ncov'), plt.colorbar(cax1, ax=ax1)
cax2 = ax2.imshow(ktr_mask, interpolation='none', cmap='inferno', origin='lower') 
ax2.set_title('kappa true masked'), plt.colorbar(cax2, ax=ax2)
plt.show()

# %% [markdown]
# ### Kaiser-Squires inversion

# %%
# Compute once the Fourier kernels for the transform
k1, k2 = np.meshgrid(np.fft.fftfreq(npix), np.fft.fftfreq(npix))
denom = k1*k1 + k2*k2
denom[0, 0] = 1  # avoid division by 0
kernel1 = (k1**2 - k2**2)/denom
kernel2 = (2*k1*k2)/denom

def kappa_to_gamma(kappa):
    k = np.fft.fft2(kappa)
    g1 = np.fft.ifft2(kernel1 * k) 
    g2 = np.fft.ifft2(kernel2 * k)
    return g1.real - g2.imag, g2.real + g1.imag 

def gamma_to_kappa(gam1, gam2):
    g = gam1 + 1j*gam2
    return np.fft.ifft2((kernel1 - 1j*kernel2)* np.fft.fft2(g))

# %%
# # # compute the Kaiser-Squares map

kks = gamma_to_kappa(e1, e2)
kkss = ndimage.filters.gaussian_filter(kks.real, sigma = 2)
kkss_mask = np.zeros_like(kkss)
kkss_mask[index] = kkss[index]
kkss_mask_flip = np.flip(kkss_mask, 1)

# %%
# # # show KS map

vvmin = np.min(kkss)
vvmax = np.max(kkss)
fig2, [ax1, ax2] = plt.subplots(nrows=1, ncols=2)
cax1 = ax1.imshow(ktr_mask_flip, interpolation='none', cmap='inferno', origin='lower', vmin = vvmin, vmax = vvmax) 
ax1.set_title('kappa true'), plt.colorbar(cax1, ax=ax1)
cax2 = ax2.imshow(kkss_mask_flip, interpolation='none', cmap='inferno', origin='lower', vmin = vvmin, vmax = vvmax) 
ax2.set_title('smooth'), plt.colorbar(cax2, ax=ax2)

plt.show()

# %% [markdown]
# ### Wiener filtering

# %%
# wiener filtering inversion

# define the kappa to shear operator
def H_operator(ka_map, kb_map):
    
    # ka_map and kb_map should be of the same size
    [nx,ny] = ka_map.shape
    
    ka_map_fft = np.fft.fft2(ka_map)
    kb_map_fft = np.fft.fft2(kb_map)
    
    f1, f2 = np.meshgrid(np.fft.fftfreq(ny),np.fft.fftfreq(nx))
    
    p1 = f1 * f1 - f2 * f2
    p2 = 2 * f1 * f2
    f2 = f1 * f1 + f2 * f2
    f2[0,0] = 1 # avoid division with zero
    kafc =  (p1 * ka_map_fft - p2 * kb_map_fft) / f2
    kbfc =  (p1 * kb_map_fft + p2 * ka_map_fft) / f2
    
    g1_map = np.fft.ifft2(kafc).real
    g2_map = np.fft.ifft2(kbfc).real
    
    return g1_map, g2_map


# define the shear to convergence operator
def H_adjoint(g1_map, g2_map):
    
    [nx,ny] = g1_map.shape
    
    g1_map_ifft = np.fft.ifft2(g1_map)
    g2_map_ifft = np.fft.ifft2(g2_map)
    
    f1, f2 = np.meshgrid(np.fft.fftfreq(ny),np.fft.fftfreq(nx))
    
    p1 = f1 * f1 - f2 * f2
    p2 = 2 * f1 * f2
    f2 = f1 * f1 + f2 * f2
    f2[0,0] = 1
    g1fc =  (p1 * g1_map_ifft + p2 * g2_map_ifft) / f2
    g2fc =  (p1 * g2_map_ifft - p2 * g1_map_ifft) / f2
    
    kappa1 = np.fft.fft2(g1fc).real
    kappa2 = np.fft.fft2(g2fc).real
    
    return kappa1, kappa2

def compute_spectrum_map(Px,size):
    power_map = np.zeros((size, size), dtype = float)
    k_map =  np.zeros((size, size), dtype = float)

    for (i,j), val in np.ndenumerate(power_map):

        k1 = i - size/2.0
        k2 = j - size/2.0
        k_map[i, j] = (np.sqrt(k1*k1 + k2*k2))

        if k_map[i,j]==0:
            #print(i,j)
            power_map[i, j] = 1e-15
        else:
            #print(k_map[i, j])
            power_map[i, j] = Px[int(k_map[i, j])]
    return power_map


def prox_wiener_filtering(gamma1, gamma2, Px_map, Ncv):
        
    # initiallize
    nx = gamma1.shape[0]
    xg = np.zeros((nx,nx)) + 1j * np.zeros((nx,nx))
    
    # find the minimum noise variance
    tau = np.min(Ncv)
    
    # set the step size
    eta = 1.83 * tau
    
    # compute signal coefficient
    Esn = eta / Ncv
    
    # calculate the wiener filter coefficients
    Wfc = Px_map / (Px_map + eta)
    
    n_iter = 100
    for n in range(n_iter):
        t1,t2 = H_operator(xg.real, xg.imag)                              # H * xg
        t1,t2 = H_adjoint(Esn*(gamma1 - t1), Esn*(gamma2 - t2))           # H^T(eta / Sn * (y- H * xg))
        t = xg + (t1 + 1j*t2)                                             # xg + H^T(eta / Sn * (y- H * xg))
        
        xg = np.fft.ifft2(np.fft.fftshift(Wfc * np.fft.fftshift(np.fft.fft2(t)))) # wiener filtering in fourier space
        
    return xg.real, xg.imag

(kwnr,kpwb) = prox_wiener_filtering(e1, e2, compute_spectrum_map(ps1d,npix), Ncov)
    
kwnr_mask = np.zeros_like(kwnr)
kwnr_mask[index] = kwnr[index]
kwnr_mask_flip = np.flip(kwnr_mask, -1)

# %%
# check wiener c++ and wiener python
try: 
    kwrc = fits.getdata('../build/kwiener.fits') # this file is produced after running c++ code 
    
    kwrc_mask = np.zeros_like(kwrc)
    kwrc_mask[index] = kwrc[index]
    kwrc_mask_flip = np.flip(kwrc_mask, -1)
    
    vvmin = np.min(kwrc)
    vvmax = np.max(kwrc)
    fig1, [ax1, ax2] = plt.subplots(nrows=1, ncols=2)
    cax1 = ax1.imshow(kwnr_mask_flip, interpolation='none', cmap='inferno', origin='lower', vmin = vvmin, vmax = vvmax)  
    ax1.set_title('kappa wiener python'), plt.colorbar(cax1, ax=ax1)
    cax2 = ax2.imshow(kwrc_mask_flip, interpolation='none', cmap='inferno', origin='lower', vmin = vvmin, vmax = vvmax) 
    ax2.set_title('kappa wiener c++'), plt.colorbar(cax2, ax=ax2)

    plt.show()
except:
    print('Wiener filtering c++ map missing')

# %%
# check the fast glimpse map on the residual shear

kfgl = fits.getdata('../data/mice/fits_files/kappa_mice_fast_glimpse_0.fits') # if wiener is enabled, this is the result of fast Glimpse on the residual shear

kfgl_mask = np.zeros_like(kfgl)
kfgl_mask[index] = kfgl[index]
kfgl_mask_flip = np.flip(kfgl_mask, 1)

vvmin = .1 # np.min(kfgl)
vvmax = -.1 # np.max(kfgl)
    
fig1, [ax1, ax2] = plt.subplots(nrows=1, ncols=2)
cax1 = ax1.imshow(ktr_mask_flip, interpolation='none', cmap='inferno', origin='lower',vmin=vvmin,vmax=vvmax)
ax1.set_title('kappa from survey'), plt.colorbar(cax1, ax=ax1)
cax2 = ax2.imshow(kfgl_mask_flip, interpolation='none', cmap='inferno', origin='lower',vmin=vvmin,vmax=vvmax)
ax2.set_title('glimpse on the residual shear'), plt.colorbar(cax2, ax=ax2)

plt.show()

# %% [markdown]
# #### glimpse plus wiener

# %%
# check the glimpse plus wiener result

kf_mask_flip = kwrc_mask_flip + kfgl_mask_flip

vvmin = -.017 #np.min(kwiener)
vvmax =  .017 #np.max(kfinal)

fig1, [ax1, ax2] = plt.subplots(nrows=1, ncols=2)
cax1 = ax1.imshow(ktr_mask_flip, interpolation='none', cmap='inferno', origin='lower',vmin=vvmin,vmax=vvmax) 
ax1.set_title('kappa from survey'), plt.colorbar(cax1, ax=ax1)
cax2 = ax2.imshow(kf_mask_flip, interpolation='none', cmap='inferno', origin='lower',vmin=vvmin,vmax=vvmax) 
ax2.set_title('residual glimpse plus wiener'), plt.colorbar(cax2, ax=ax2)

fig2, [ax1, ax2] = plt.subplots(nrows=1, ncols=2)
cax2 = ax2.imshow(kf_mask_flip, interpolation='none', cmap='inferno', origin='lower',vmin=vvmin,vmax=vvmax) 
ax2.set_title('residual glimpse'), plt.colorbar(cax2, ax=ax2)
cax1 = ax1.imshow(kwrc_mask_flip, interpolation='none', cmap='inferno', origin='lower',vmin=vvmin,vmax=vvmax) 
ax1.set_title('wiener'), plt.colorbar(cax1, ax=ax1)

plt.show()

# calculate mse
ktrue_vec = np.reshape(ktr_mask[index], -1) - np.mean(np.reshape(ktr_mask[index], -1))
kkss_vec = np.reshape(kkss_mask[index], -1) - np.mean(np.reshape(kkss_mask[index], -1))
kwrc_vec = np.reshape(kwrc_mask[index], -1) - np.mean(np.reshape(kwrc_mask[index], -1))
# kgl_old_vec = np.reshape(kgl_mask[index],-1) - np.mean(np.reshape(kgl_mask[index], -1))
# kfgl_vec = np.reshape(kfgl_mask[index],-1) - np.mean(np.reshape(kfgl_mask[index], -1))
# kwgl_vec = np.reshape(kwgl_mask[index], -1)  - np.mean(np.reshape(kwgl_mask[index], -1))

mse_kkss     = np.linalg.norm(ktrue_vec - kkss_vec, 2)**2 / np.linalg.norm(ktrue_vec,2)**2
mse_kwnr     = np.linalg.norm(ktrue_vec - kwrc_vec, 2)**2 / np.linalg.norm(ktrue_vec,2)**2
# mse_kgl_old  = np.linalg.norm(ktrue_vec - kgl_old_vec,2)**2 / np.linalg.norm(ktrue_vec,2)**2
# mse_kfgl     = np.linalg.norm(ktrue_vec - kfgl_vec,2)**2 / np.linalg.norm(ktrue_vec,2)**2
# mse_kwgl     = np.linalg.norm(ktrue_vec - kwgl_vec, 2)**2 / np.linalg.norm(ktrue_vec,2)**2
print('MSE KSs:   \t', mse_kkss)
print('MSE wiener: \t', mse_kwnr)
# print('MSE glimpse: \t', mse_kgl_old)
# print('MSE dft glimpse: ', mse_kfgl)
# print('MSE wglimpse: \t', mse_kwgl)
# Out:
# MSE KSs:   	 1.3904552392
# MSE wiener: 	 0.917509966785

# %%
# # # check thresholds

thres = fits.getdata('../build/thresholds.fits')

for i in range(0,thres.shape[0],2):
    fig1, [ax1, ax2] = plt.subplots(nrows=1, ncols=2)
    cax1 = ax1.imshow(thres[i,:,:], interpolation='none', cmap='inferno') 
    ax1.set_title('thresholds scale ' + str(i)), plt.colorbar(cax1, ax=ax1)
    cax2 = ax2.imshow(thres[i+1,:,:], interpolation='none', cmap='inferno') 
    ax2.set_title('thresholds scale ' + str(i+1)), plt.colorbar(cax2, ax=ax2)

plt.show()
